# %% [markdown]
# <a href="https://colab.research.google.com/github/fisher133269/coco/blob/main/pa2b_assignment_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2 Part B - Face Classification
#
# Welcome to the second part of the second assignment!
#
# Make sure to:
# 1. Read the writeup before doing anything here
# 2. Read instructions for each problem carefully
#     - This pipeline is large and potentially confusing; it's important you do it right to avoids bugs and develop a better understanding.

# %% [markdown]
# ## Setup/Importing

# %%
# Run this cell and follow instructions to connect this notebook to Google Drive
try:
    from google.colab import drive
    drive.mount('/content/drive')
except ImportError:
    print("Not on google drive")
# Out:
# Mounted at /content/drive

# %%
# Change directories ("cd") to the folder containing your
# notebook and data folder by replacing the filepath below
# %cd path/to/folder/in/google/drive
# Out:
# [Errno 2] No such file or directory: 'path/to/folder/in/google/drive'
# /content

# %%
# TODO Run this cell to download the data from Amazon AWS
# TODO If needed, replace your the local Google Drive path (/content/drive/MyDrive/pa2b/) with a path that works for you

# !wget -P /content/drive/MyDrive/pa2b/ https://cmu-dele-leaderboard-us-east-2-003014019879.s3.us-east-2.amazonaws.com/colab/pa2b/data2pb.zip
# Out:
# --2022-11-24 05:09:11--  https://cmu-dele-leaderboard-us-east-2-003014019879.s3.us-east-2.amazonaws.com/colab/pa2b/data2pb.zip
# Resolving cmu-dele-leaderboard-us-east-2-003014019879.s3.us-east-2.amazonaws.com (cmu-dele-leaderboard-us-east-2-003014019879.s3.us-east-2.amazonaws.com)... 52.219.97.146
# Connecting to cmu-dele-leaderboard-us-east-2-003014019879.s3.us-east-2.amazonaws.com (cmu-dele-leaderboard-us-east-2-003014019879.s3.us-east-2.amazonaws.com)|52.219.97.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 742735299 (708M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/pa2b/data2pb.zip.1’
#
# data2pb.zip.1       100%[===================>] 708.33M  15.3MB/s    in 49s
#
# 2022-11-24 05:10:01 (14.5 MB/s) - ‘/content/drive/MyDrive/pa2b/data2pb.zip.1’ saved [742735299/742735299]

# %%
# TODO Run this cell to unzip the data from Amazon AWS to your local Drive
# TODO If needed, replace your the local Google Drive path (/content/drive/MyDrive/pa1b/data1pb.zip) with a path that works for you

# !unzip -u /content/drive/MyDrive/pa2b/data2pb.zip -d /content/drive/MyDrive/pa2b/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044009.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042440.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065264.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032952.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056595.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018770.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065216.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014386.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008370.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059334.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040070.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027433.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045667.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018674.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00034240.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049315.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027188.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002536.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005336.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035101.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057024.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048587.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033476.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027272.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045303.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00041968.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053197.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038897.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038919.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025681.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042673.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003005.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062045.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043931.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004937.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024217.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00037689.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00006860.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065149.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010632.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003293.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045847.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025563.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003024.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063888.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044481.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056349.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00015022.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058079.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00006609.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067445.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036503.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005989.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043353.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046150.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067952.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046820.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054619.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048255.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00016036.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00006908.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020760.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067094.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059790.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032310.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054140.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035131.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024473.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064798.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024860.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030991.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000160.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065568.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008616.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059857.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053063.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053886.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063609.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000341.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042378.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028427.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000073.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031922.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008275.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046448.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036001.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000335.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004798.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026007.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068489.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000497.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046653.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004938.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020773.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058646.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035261.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046575.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049571.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002342.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044088.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014735.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010855.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020368.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00019714.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066889.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009255.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000787.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010348.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047272.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027359.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00001426.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024898.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033901.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050156.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061442.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00037176.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042942.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00011659.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057759.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00012514.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00013080.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00016108.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008298.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017026.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054327.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024132.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027460.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004553.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00037962.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043779.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032913.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00037894.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00015142.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00022082.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066940.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008044.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068202.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040679.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066403.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008929.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010844.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054676.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049537.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028430.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036498.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056730.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039307.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000598.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038835.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050607.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032749.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033532.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038516.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048016.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056291.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052707.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003046.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064928.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042898.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033706.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059027.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038721.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009526.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002712.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038691.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038250.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061512.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002636.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009704.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004323.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028577.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059267.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025583.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030389.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00015584.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068296.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008414.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009869.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040108.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046924.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035352.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031936.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036674.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030950.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000711.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052602.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055948.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008487.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00001558.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065164.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00013708.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005384.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021891.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009247.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00023670.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040463.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040635.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021306.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054217.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002539.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042178.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00029873.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045633.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017500.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066740.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042983.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026840.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00001332.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027904.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003933.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00022168.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039682.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008257.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00060574.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054767.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000876.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00029667.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055740.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049093.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061138.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042551.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039203.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038764.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057984.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042684.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024347.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048139.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028109.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046447.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004034.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049589.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028759.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000610.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066700.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004183.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043136.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00019912.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014476.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026486.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00013919.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062204.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00006495.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025562.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00051487.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010488.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036816.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033884.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00037246.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021984.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028969.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00007425.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062870.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055492.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059331.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00034934.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018815.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063932.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058384.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00029700.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044179.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030527.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059084.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058297.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042152.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00012244.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024085.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00069086.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000337.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039490.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064550.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027122.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00013184.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035688.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00060109.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063414.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039186.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050888.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017782.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045079.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005968.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004493.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028434.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052001.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046902.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024117.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024911.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00023814.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048202.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065008.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044996.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030137.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00060068.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052487.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067091.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00060892.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032468.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049999.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000657.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00051509.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053351.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017702.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058130.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00011490.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054551.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035379.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003041.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031652.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044581.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058517.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00007040.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065010.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053662.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038413.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031127.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002443.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009619.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048161.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003539.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062500.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027207.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056287.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042584.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008547.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00016208.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038833.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024264.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00001958.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061216.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035663.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052927.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021107.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00051891.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064981.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009079.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036728.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00016233.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068341.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050080.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002416.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00013777.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033608.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00012801.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009309.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00029726.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055066.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068094.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066714.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00006459.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062654.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064102.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038820.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066692.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009599.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00022776.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024762.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009762.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028693.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030529.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00015400.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028968.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003142.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039339.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00012485.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026824.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049542.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050189.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010962.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039561.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064742.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047200.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048204.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068192.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044896.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043801.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00013577.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020503.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030257.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036815.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025389.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00023537.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020507.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00011107.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033397.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054431.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067513.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031597.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00023995.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062218.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004590.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036641.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066475.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00034816.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021477.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00001430.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00069065.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035099.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061345.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00012601.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062048.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054199.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058920.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003547.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052762.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00037079.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065139.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005647.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008065.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049170.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00029803.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048920.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020758.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025462.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005102.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024467.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010308.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054713.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061646.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026038.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052519.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010416.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064583.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062142.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025179.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054405.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00042668.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049563.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046280.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063533.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021570.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018097.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036551.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021106.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021490.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004342.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00022549.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035633.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024706.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00023177.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056248.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035519.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00015244.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065322.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00006294.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033444.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043300.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065811.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067223.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068409.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025876.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00006712.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021529.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020354.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047192.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026921.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063508.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030581.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057187.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058764.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00069010.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056134.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00022926.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00037693.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031274.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00041547.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044606.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024699.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057913.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058446.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032339.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047047.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024630.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030340.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066083.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043493.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00041238.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063320.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053218.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025887.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045900.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00051362.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047478.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036971.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054591.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057743.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00011261.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014738.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052529.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00007511.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040612.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066562.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038944.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039988.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000152.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033121.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054148.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047641.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039757.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045248.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00049609.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052854.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031296.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065687.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00019292.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027483.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055430.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00023625.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039953.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038437.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052041.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00016606.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057785.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024635.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00016862.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057252.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031162.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039912.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045699.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032281.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018772.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066231.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056055.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00060424.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028414.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000678.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063430.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00007776.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025506.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00012138.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052780.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018816.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067298.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040724.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028884.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032239.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00019146.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009167.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061643.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00012855.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040850.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043981.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068866.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043114.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014553.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055443.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00041374.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033940.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030566.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047677.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038630.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00021203.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066597.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068457.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035723.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048239.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032079.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00011544.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064987.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014493.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00006662.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026160.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005549.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00011698.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00019752.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033536.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046492.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00007865.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00034600.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047436.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047186.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044499.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005709.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014724.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00023310.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00060997.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055116.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047684.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057411.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027773.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017144.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00007916.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00022345.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00069035.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026692.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050108.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026494.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004795.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045589.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059949.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038715.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014886.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047746.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030214.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005224.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061829.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025393.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050361.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031632.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056074.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056297.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017430.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050878.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061095.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040333.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045525.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032162.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035872.jpg
# ...
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002006.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024733.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004265.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008977.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025039.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024030.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00001595.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030128.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010153.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002995.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027792.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039716.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002400.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052654.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004601.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008139.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00041197.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026994.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00022832.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030230.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059646.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046139.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00060236.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055923.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00029924.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036414.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031072.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055642.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065655.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00060377.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058365.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050922.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057510.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027426.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067322.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00034730.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067971.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068646.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008626.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00065981.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004036.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00011345.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010693.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044224.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008536.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000814.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00010928.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00023268.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046624.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00015254.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030237.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024389.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024258.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061441.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00041623.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00013744.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018069.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033219.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017095.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025528.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00037663.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018305.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045018.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035210.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046029.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00006053.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00012045.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014942.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053553.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064343.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004627.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039744.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066277.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058639.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047217.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053107.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043986.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035607.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00019353.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00048955.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058559.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00035405.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063558.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004476.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00058256.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038271.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066599.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00009125.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039495.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00001765.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018205.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020988.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036761.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036440.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017289.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00008087.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00034384.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038531.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00054459.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045408.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00027101.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003720.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00013507.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040030.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00050403.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00001911.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020415.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00016183.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00022483.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00003324.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014838.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066481.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00051215.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00005957.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032476.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00060882.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018699.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045800.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025465.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00001181.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00012550.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059263.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036784.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055527.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00059116.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00051665.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036403.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020855.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00052196.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061582.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00004676.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00056164.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00023331.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00051552.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057357.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030453.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00044916.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00034764.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017912.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00041955.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040640.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000916.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00040729.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00064879.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062169.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00025702.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068525.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00019829.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032651.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020609.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043146.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00066201.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00036537.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00068291.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00031470.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047730.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018081.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053970.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00028270.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00024321.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00015911.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00020949.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00000671.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00039686.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00063561.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00034088.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038170.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00030345.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045644.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017349.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00015112.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00029502.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00046981.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067221.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00057136.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00038752.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00034432.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00026725.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00018949.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045488.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00033077.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067290.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00067099.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00002635.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053824.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053956.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00053463.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00055358.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00029742.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00011363.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00017094.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00061213.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00045998.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00043108.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00032984.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00014435.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00047680.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_data/00062130.jpg
#   inflating: /content/drive/MyDrive/pa2b/data/verification_pairs_val.txt
#   inflating: /content/drive/MyDrive/pa2b/data/pa2b_solution.csv
#   inflating: /content/drive/MyDrive/pa2b/data/pa2b_sample.csv
#   inflating: /content/drive/MyDrive/pa2b/data/verification_sample_submission.csv
#   inflating: /content/drive/MyDrive/pa2b/data/classification_test.txt

# %%
# Run this cell to import packages and enable autoreloading code from other imported files
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm.notebook import tqdm
import torchvision
import os

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Auto-detect if GPU is available

# %%
# Run this cell to automatically detect if GPU is available.
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(DEVICE)
# Out:
# cpu

# %%
ls
# Out:
# drive/  sample_data/

# %% [markdown]
# # Section 1: Datasets/DataLoaders

# %% [markdown]
# ## Question 1.1: Initialize Training/Validation Datasets for Classification
# As discussed in section 5 of the writeup, load in the **training** and **validation** datasets for classification.
#
# You'll want to use the [ImageFolder](https://pytorch.org/vision/stable/datasets.html#torchvision.datasets.ImageFolder) object from `torchvision`. Read the documentation for it to figure out how to initialize it. You'll need the paths to the classification train/val folders.

# %%
# [Given] Method for transforming image data to a tensor, give this to ImageFolder
transform = torchvision.transforms.ToTensor() # give this to the ImageFolder object

# TODO: Initialize dataset objects for training and validation using ImageFolder from torchvision.
classification_train_dataset = None
classification_val_dataset = None

### BEGIN SOLUTION
classification_train_dataset = torchvision.datasets.ImageFolder("data/classification_train", transform=transform)
classification_val_dataset = torchvision.datasets.ImageFolder("data/classification_val", transform=transform)
### END SOLUTION
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-edb7ad0bf4f4> in <module>
#       7
#       8 ### BEGIN SOLUTION
# ----> 9 classification_train_dataset = torchvision.datasets.ImageFolder("data/classification_train", transform=transform)
#      10 classification_val_dataset = torchvision.datasets.ImageFolder("data/classification_val", transform=transform)
#      11 ### END SOLUTION
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     314             transform=transform,
#     315             target_transform=target_transform,
# --> 316             is_valid_file=is_valid_file,
#     317         )
#     318         self.imgs = self.samples
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     143     ) -> None:
#     144         super().__init__(root, transform=transform, target_transform=target_transform)
# --> 145         classes, class_to_idx = self.find_classes(self.root)
#     146         samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     147
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in find_classes(self, directory)
#     217             (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     218         """
# --> 219         return find_classes(directory)
#     220
#     221     def __getitem__(self, index: int) -> Tuple[Any, Any]:
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in find_classes(directory)
#      39     See :class:`DatasetFolder` for details.
#      40     """
# ---> 41     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      42     if not classes:
#      43         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/classification_train'

# %% [markdown]
# ## Question 1.2: Initialize Classification DataLoaders
# Now that you have the datasets initialized, give each of them to a [DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader).
#
# **DataLoader Hyperparam Notes**
#
# Set the args for the `DataLoader` based on these notes. This assignment is really compute/memory intensive, so these will make a big difference in speeding up training.
#
# - `batch_size`
#     - See assignment 1b writeup for how to select `batch_size`.
#         - `64` is a decent starting number for the train dataset.
#     - Validation/test can have larger `batch_size`, this will speed up eval
#         - In general, we want to maximize val/test batch sizes because we just need to get through them quickly, and because it has no impact on training or the final accuracy score.
#         - We can do larger batch sizes training because we have more free memory available, because no gradients are stored during eval.
# - `pin_memory`
#     - Read this [page](https://pytorch.org/docs/stable/data.html#memory-pinning), set to `True`
# - `num_workers`
#     - Given below. We set to the number of CPU cores you have available.
#         - You can use this same value for train, val, and test.
#     - For what this does, read this [page](https://pytorch.org/docs/stable/data.html#single-and-multi-process-data-loading)

# %%
# [Given] How many "workers" (multi-processing parallel threads) each dataloader should have.
num_workers = os.cpu_count()
print(f"num_workers (# cpu cores): {num_workers}")

# TODO: Initialize `Dataloader` objects.
classification_train_dataloader = None
classification_val_dataloader = None

### BEGIN SOLUTION
batch_size = 64
classification_train_dataloader = torch.utils.data.DataLoader(classification_train_dataset, batch_size=batch_size, pin_memory=True, shuffle=True, num_workers=num_workers)
classification_val_dataloader = torch.utils.data.DataLoader(classification_val_dataset, batch_size=batch_size, pin_memory=True, shuffle=False, num_workers=num_workers)
### END SOLUTION

# %% [markdown]
# ## Question 1.3: Initialize Val Verification Dataset/Dataloader
#
# We need this because, while training on classification, we also want to see how our model is doing on verification every epoch.
#
# We only initialize the validation set for now, because the test set is only needed at the very end of the assignment when you want to generate your submission for grading.

# %%
from utils import VerificationDataset

# [Given] Custom dataset object for verification task. See utils.py for its implementation.
verify_verification_dataset = VerificationDataset("data", "data/verification_pairs_val.txt")

# TODO: Initialize `Dataloader` object (similar to above question)
verification_val_dataloader = None

### BEGIN SOLUTION
batch_size = 64
verification_val_dataloader = torch.utils.data.DataLoader(verify_verification_dataset, batch_size=batch_size, pin_memory=True, shuffle=False, num_workers=num_workers)
### END SOLUTION

# %% [markdown]
# # Section 2: ResNet Model
#
# Now let's implement your model: ResNet.
#
# <!--
# Note that our model is a class that extends `nn.Module`. Extending `nn.Module` means that any `nn.Module`s assigned as attributes to the class will automatically have their parameters absorbed. So when we do the following:
#
#     model = Model()
#     optimizer = MyOptimizer(model.parameters())
#
# Any attributes of `model` that have parameters will have those parameters included in `model.parameters()`, so `optimizer` will optimize them during training. -->

# %% [markdown]
# ## Question 2.1: `ResBlock`
#
# <p align="center"><img src="images/resblock_downsample_false.png" width="400"/><img src="images/resblock_downsample_true.png" width="411"/></p>
#
# Recall that ResNet is composed of these modular `ResBlock` units that are simply stacked together with differing parameters to get the final model.
#
# Also recall that the block differs depending on whether `downsample` is `False` or `True`.
#
# - If `downsample=False` (left-side of diagram), the output's width/height will end up unchanged from the input's.
# - If `downsample=True` (right-side of diagram), the output's width/height end up smaller than the input's.
#
# For both cases, the number of output channels depends solely on how you specify `out_channels`.
#
# <p align="center"><img src="images/residual_sizes_downsample_false.png" width="400"/><img src="images/residual_sizes_downsample_true.png" width="411"/></p>
#
# The above diagram shows how to specify layer sizes for both the `downsample=False` case and the `downsample=True` case.
#
# Most important differences:
#
# - If `downsample=False`, the shortcut should be `nn.Identity()`, and the first `Conv1d` in `self.residual` should have `stride=1`.
# - If `downsample=True`, the shortcut should be the block shown on the bottom right, and the first `Conv1d` in `self.residual` should have `stride=2`.
#
# **Instructions:**
#
# Implement `ResBlock.__init__()` and `ResBlock.forward()` below. The `# TODO` comments should walk you through what to implement.

# %%
mkdir images

# %%
class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, downsample=False):
        super().__init__()
        # TODO: Initialize the residual EXCLUDING the last `ReLU`.
        # Your stride for the first layer will need to depend on the `downsample` variable.
        self.residual = nn.Sequential(
            # Add appropriate layers here
        )

        # TODO: Implement the shortcut (right side of diagram) based on whether or not `downsample` is True or False
        if downsample:
            self.shortcut = nn.Sequential(
                # Add appropriate layers here
            )
        else:
            # TODO: If no downsampling, use an Identity layer
            self.shortcut = None

        # TODO: Implement the final ReLU activation function
        self.final_activation = None

        ### BEGIN SOLUTION
        self.residual = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride=2 if downsample else 1, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding=1),
            nn.BatchNorm2d(out_channels),
        )

        if downsample:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, 1, 2),
                nn.BatchNorm2d(out_channels)
            )
        else:
            self.shortcut = nn.Identity()

        self.final_activation = nn.ReLU()
        ### END SOLUTION

    def forward(self, x):
        # TODO: pass the input through the residual (don't overwrite `x`!)
        residual_out = None

        # TODO: pass the input through the shortcut
        shortcut_out = None

        # TODO: add the shortcut and residual outputs, and pass them through the final activation
        final_out = None

        ### BEGIN SOLUTION
        shortcut_out = self.shortcut(x)
        residual_out = self.residual(x)
        final_out = self.final_activation(shortcut_out + residual_out)
        ### END SOLUTION

        return final_out

# %% [markdown]
# ## Question 2.2: `ResNet`
#
# Now we can implement the overall model.
#
# First, implement `ResNet.__init__()`. Begin by implementing the table with our recommended architecture from the writeup.
#
# You definitely can modify the widths/depths yourself later, but you'll need to carefully ensure the sizes will line up.
#
# Second, implement `ResNet.forward()`.

# %%
class ResNet(nn.Module):
    def __init__(self):
        super().__init__()
        # TODO: Implement the first Conv2d layer
        self.conv = None

        # TODO: Implement a nn.Sequential containing the ResBlocks.
        self.blocks = nn.Sequential(
            # Add appropriate layers here, make sure to set downsample appropriately.
        )
        self.linear = None
        ### BEGIN SOLUTION
        self.conv = nn.Conv2d(3, 64, 3, 1, padding=1)
        self.blocks = nn.Sequential(
            ResBlock(64, 64, 3),
            ResBlock(64, 64, 3),

            ResBlock(64, 128, 3, True),
            ResBlock(128, 128, 3),

            ResBlock(128, 256, 3, True),
            ResBlock(256, 256, 3),

            ResBlock(256, 512, 3, True),
            ResBlock(512, 512, 3),
        )

        self.linear = nn.Linear(512, 4000)
        ### END SOLUTION

    def forward(self, x):
        # TODO: Pass the input through the first convolution
        conv_out = None

        # TODO: Pass conv_out through the ResBlocks
        block_out = None

        # TODO: Average the output along the last two axes to get the embedding
        features = None

        # TODO: Pass the features through the final linear layer
        logits = None

        # this function should return (embedding, logits)
        ### BEGIN SOLUTION
        features = self.blocks(self.conv(x)).mean(2).mean(2)
        logits = self.linear(features)
        ### END SOLUTION

        # [Given] Return both the logits AND features; will need logits for classification, features for verification
        return logits, features

# %% [markdown]
# Run the cell below to initialize your model.
#
# If there are any errors/exceptions thrown during the initialization, you likely made a mistake during implementation somewhere. But even if there are no errors thrown, you could have still made a mistake! It'll become apparent when you run your training loop for the first time.
#
# This is a good opportunity to learn how to read the error messages and debug neural networks. Remember: the `%debug` Jupyter notebook command is really useful.

# %%
# Run this cell to initialize your model
model = ResNet()
model = model.to(DEVICE)

# make sure the model initializes properly
print(model)

# %% [markdown]
# # Section 3: Training/Validation/Prediction Routines
#
# Now to write the training/eval routines.
#
# Below, we've given you the overall `train()` method. It should look mostly familiar, but the main difference is that we do **two validations** every epoch:
#
# One validation on the **classification** task, and a second for the **verification** task.
#
# We do this to get a sense of how our model is doing for each task.

# %%
# [Given] ALREADY COMPLETED, SHOWN JUST FOR YOUR REFERENCE
def train(model, optimizer, classification_train_dataloader, classification_val_dataloader,
          verification_val_dataloader, num_epochs, scheduler=None, center_loss_function=None):
    """[Given] Trains and validates network for given number of epochs

    Args:
        model (nn.Module): Your initialized ResNet model.
        optimizer (optim.Optimizer): Initialized optimizer like `optim.SGD` or `optim.Adam`
        classification_train_dataloader (torch.utils.data.DataLoader): Classification train dataloader
        classification_val_dataloader (torch.utils.data.DataLoader): Classification val dataloader
        verification_val_dataloader (torch.utils.data.DataLoader): Verification val dataloader
        num_epochs (int): Number of epochs to train for
        scheduler (optim.lr_scheduler): Initialized scheduler like `optim.lr_scheduler.ReduceLROnPlateau` (or None)
    Returns:
        (list, list): a list of loss values per batch and a list of validation accuracies every epoch
    """
    losses = []
    val_accuracies = []

    for e in range(num_epochs):
        print(f"Epoch #{e}")
        epoch_losses = train_epoch(model, optimizer, classification_train_dataloader, \
                                   scheduler, center_loss_function)
        losses.extend(epoch_losses)

        # Eval on classification validation set
        val_accuracy = eval_classification(model, classification_val_dataloader)
        print("Classification Val Accuracy:", 100 * val_accuracy)

        # Eval on verification validation set
        verification_accuracy = eval_verification(model, verification_val_dataloader)
        print("Verification Val ROC AUC:", 100 * verification_accuracy)
        val_accuracies.append(val_accuracy)


    return losses, val_accuracies

# %% [markdown]
# Also given below is the evaluation method for classification.  It's very similar to the previous assignments', so we figured we'd just give it to you.

# %%
# [Given] ALREADY COMPLETED, SHOWN JUST FOR YOUR REFERENCE
def eval_classification(model, dataloader):
    """[Given] Evaluates network and calculates accuracy for a full validation dataset.

    Args:
        model (nn.Sequential): Your initialized network, stored in a `Sequential` object.
        dataloader (torch.utils.data.DataLoader): Initialized validation dataloader

    Returns:
        float: Accuracy rate for entire val set.
    """
    model.eval()
    total_correct = 0
    # Run faster by ignoring information necessary for calculating gradients
    with torch.no_grad():
        for i, (data, labels) in tqdm(enumerate(dataloader), total=len(dataloader)):
            # Put tensors on specified device
            data, labels = data.to(DEVICE), labels.to(DEVICE)

            # Get the two outputs of ResNet.forward()
            logits, features = model(data) # Note that we don't need `features` so we just ignore it.

            # Get integer predictions by taking the max index along the `logits`. Then compare against the labels.
            num_correct = (logits.argmax(axis=1) == labels).sum()

            total_correct += num_correct.item()

    return total_correct / len(dataloader.dataset)

# %% [markdown]
# ## Question 3.1: `eval_verification()`
#
# Now you'll implement evaluation on the **verification** task.
#
# **Overview**
#
# Instead of calculating accuracy, this method calculates the [Area Under the Curve (AUC) of the ROC curve](https://en.wikipedia.org/wiki/Receiver_operating_characteristic#Area_under_the_curve), which is a common metric for evaluating binary classifiers. Remember, this problem is binary classification: are these two images of the same person or not?
#
# To do this, we first need to calculate the predicted cosine similarity scores for each pair of images in the verification val set. Once we have those, we can calculate the AUC ROC and return it.
#
# **Methodology**
# - We iterate through the `verification_val_dataloader` to get our pairs of images.
#     - Each iteration, we get two batches of images. For example, if `batch_size=5`, we get two batches that each contain 5 images.
#     - We give the model each batch, one at a time.
#         - Doesn't matter which batch you provide first
#     - We grab the `feature` matrix the model outputs for each batch, and give them to our initialized `nn.CosineSimilarity` module
#     - This should return all of the cosine similarity scores for the batch. `extend` the given `similarities` list with these scores.
# - After calculating all of the cosine similarity scores, we give these and the true binary labels to `roc_auc_score` function
#     - The function is imported for you in the next cell
# - The output of `roc_auc_score` is a single float, representing your ROC AUC score for the entire verification val dataset.

# %%
from sklearn.metrics import roc_auc_score

def eval_verification(model, verification_val_dataloader):
    """[Given] Evaluates network and calculates ROC AUC for a full validation dataset.

    Args:
        model (nn.Module): Self-explanatory!
        verification_val_dataloader (torch.utils.data.DataLoader): Initialized verification val dataloader

    Returns:
        float: ROC AUC for entire val set.
    """
    model.eval()

    # TODO: Initialize the nn.CosineSimilarity object from torch
    cosine_similarity = None
    ### BEGIN SOLUTION
    cosine_similarity = nn.CosineSimilarity()
    ### END SOLUTION

    # [Given] Cosine similarity scores go here
    similarities = []

    with torch.no_grad():
        for (batch_1, batch_2, _) in tqdm(verification_val_dataloader, total=len(verification_val_dataloader)):
            # [Given] Put batches on GPU
            batch_1, batch_2 = batch_1.to(DEVICE), batch_2.to(DEVICE)

            # TODO: Give each batch to the model, store the feature output of each
            ### BEGIN SOLUTION
            _, features_1 = model(batch_1)
            _, features_2 = model(batch_2)
            ### END SOLUTION

            # TODO: Give the feature vectors to cosine_similarity, get the scores
            batch_similarities = None
            ### BEGIN SOLUTION
            batch_similarities = cosine_similarity(features_1, features_2)
            ### END SOLUTION

            # [Given] Store the similarity scores
            similarities.extend(batch_similarities.tolist())

    # [Given] List of binary labels for the entire dataset
    labels = verification_val_dataloader.dataset.get_labels()

    # TODO: Give the labels and the similarities to the roc_auc_score function, return the final score
    auc_score = None
    ### BEGIN SOLUTION
    auc_score = roc_auc_score(labels, similarities)
    ### END SOLUTION

    return auc_score

# %% [markdown]
# ## Question 3.2: `train_epoch()`
#
# Now to write the training routine of a single epoch.
#
# **Note: If you haven't already, read section 6 of the writeup for explanations of mixed precision and center loss.**
#
# The pseudocode below reflects the usage of both techniques. Note that we're giving you parts of this because it's pretty complicated and the main point of this exercise is the concepts.
#
# ```
# def train_epoch():
#     set_model_to_train_mode()
#     alpha = 0.005
#     grad_scaler = create_amp_gradient_scaler()
#     for (data, labels) in tqdm(dataloader):
#         data, labels = put_tensors_on_appropriate_device(DEVICE, data, labels) # See val method for how to do this
#         reset_gradients_to_zero()
#         with autocast:
#             logits, features = forward_pass_through_model(model, data)
#             center_loss = center_loss_function(features, labels) * alpha
#             loss = cross_entropy_loss_function(logits, labels) + center_loss
#         backprop_with_amp_scaled_gradients()
#         update_center_loss_params()
#         update_model_with_amp_scaled_gradients()
#         update_scaler()
#         store_loss_value(loss)
#
#     return loss_values
# ```
#
# **CenterLoss Notes:**
# - We're using the "second method" described in the [readme](https://github.com/KaiyangZhou/pytorch-center-loss), with one optimizer for model and loss function parameters.
# - Notice that `CenterLoss` has **trainable parameters**
#     - If you rerun training, you should make sure to use the same object without reinitializing it. If you initialize it again, it'll lose the centers it was training.
# - We're using `alpha=0.005` for center loss.

# %%
def train_epoch(model, optimizer, dataloader, scheduler=None, center_loss_function=None):
    """Train model for one epoch.

    Args:
        model (nn.Module): Initialized ResNet network.
        optimizer (optim.Optimizer): Initialized optimizer like `optim.SGD` or `optim.Adam`
        dataloader (torch.utils.data.DataLoader): Initialized training dataloader
        center_loss_function (CenterLoss): Initialized CenterLoss object (imported from `center_loss.py`).
        scheduler (optim.lr_scheduler): Optional scheduler if you want it

    Returns:
        list: Loss value of each batch for this epoch.
    """
    # [Given] Make sure you're aware of what's here
    loss_per_batch = []
    loss_function = nn.CrossEntropyLoss()
    alpha = 0.005

    # TODO: set model to train mode

    # TODO: initialize your AMP gradient scaler
    amp_grad_scaler = None

    ### BEGIN SOLUTION
    model.train()
    amp_grad_scaler = torch.cuda.amp.GradScaler()
    ### END SOLUTION

    # Run loop with `tqdm` progress bar
    for i, (data, labels) in tqdm(enumerate(dataloader), total=len(dataloader)):
        # TODO: Complete code based on pseudocode
        ### BEGIN SOLUTION
        data, labels = data.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()

        with torch.cuda.amp.autocast():
            logits, features = model(data)
            center_loss = center_loss_function(features, labels) * alpha
            loss = loss_function(logits, labels) + center_loss
        ### END SOLUTION

        # [Given] Run backprop on scaled gradient with AMP
        amp_grad_scaler.scale(loss).backward()

        # [Given] Manually update center loss trainable parameters
        lr = optimizer.param_groups[0]['lr']
        for param in center_loss_function.parameters():
            param.grad.data *= (1e-1 /(alpha * lr))

        # [Given] Update model parameters (equivalent to doing `optimizer.step()` without AMP)
        amp_grad_scaler.step(optimizer)
        amp_grad_scaler.update()

        # [Given] Store the loss value for the batch
        loss_per_batch.append(loss.item())

    # TODO (Optional): step the scheduler if it is not None
    ### BEGIN SOLUTION
    if scheduler is not None:
        scheduler.step(sum(loss_per_batch))
    ### END SOLUTION
    return loss_per_batch

# %% [markdown]
# # Section 4: Train Model!
#
# Almost there!

# %% [markdown]
# ## Question 4.1: Initialize objects
#
# Time to initialize objects. If things break, you may need to figure out what the error messages mean and backtrack to fix the appropriate thing.
#
# Google is your friend. Post questions if you're particularly lost.
#
# Here's a link to the [CenterLoss documentation](https://github.com/KaiyangZhou/pytorch-center-loss), and a description of [LR schedulers](https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate). A good scheduler is ReduceLROnPlateau.
#
# Note that instead of using an optimizer for center loss, and a different one for the model as suggested in the center loss docsm, we can turn both parameter sets into lists, and then concatenate them together.

# %%
from center_loss import CenterLoss

# Note: you already should have initialized your model a few cells above, but you can reinitialize it here if you want.

# TODO: Initialize center loss function (see the readme and/or center_loss.py)
center_loss_function = None

# TODO: Concatenate your model and center loss function parameters so that you can just use one optimizer;
#       this will looks like list(model.parameters()) + list(center_loss_function.parameters())
parameters = None

# TODO: Initialize optimizer with combined parameters.
optimizer = None

# TODO: (Optional) Initialize a scheduler if you want it!
scheduler = None

### BEGIN SOLUTION
center_loss_function = CenterLoss(num_classes=4000, feat_dim=512, device=DEVICE)
parameters = list(model.parameters()) + list(center_loss_function.parameters())
optimizer = torch.optim.Adam(parameters, lr=1e-3, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=0)
### END SOLUTION

# %% [markdown]
# ## Question 4.2: Run training!
#
# Now to run training! Begin by training for 8 epochs and see how it does. We encourage you to generate test results for section 5 as soon and as often as possible, so you can guarantee you'll at least earn some points before the final deadline!

# %%
# TODO: Call your training routine for some epochs
num_epochs = 8
# losses, val_accuracies = train() # TODO: Finish me!

### BEGIN SOLUTION
losses, val_accuracies = train(model, optimizer, classification_train_dataloader, \
                               classification_val_dataloader, verification_val_dataloader, \
                               num_epochs, scheduler, center_loss_function)
### END SOLUTION

# %% [markdown]
# # Section 5: Generating Test Predictions for Submitting!
#
# Now to submit! Run these cells below and look for the output file generated in the `submissions/` folder (it will be time-stamped).
#
# **NOTE:** The first two rows of the CSV should look like this:
#
# `Id,Category
# verification_data/00020839.jpg verification_data/00035322.jpg,[some number]`
#
# **Please remember to edit the second entry of the first row ('Category') to the name you want to appear on the leaderboard.**

# %%
from utils import export_predictions_to_csv, generate_predictions

test_verification_dataset = VerificationDataset("./data/", "./data/verification_pairs_test.txt", True)
test_verification_dataloader = torch.utils.data.DataLoader(test_verification_dataset, batch_size=batch_size,
                                                           pin_memory=True, shuffle=False,
                                                           num_workers = num_workers)
similarities = generate_predictions(model, test_verification_dataloader, DEVICE)
export_predictions_to_csv("data/verification_pairs_test.txt", similarities)
